# %%
import cv2
import matplotlib.pyplot as plt

# Read image
image = cv2.imread(r"Z:\MMS\lab-work-m1-AA-maker-dev-main\Lab-04\Image\1004016.jpg")

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display grayscale image
plt.imshow(gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %%
# Save grayscale image
cv2.imwrite("Image/grayscale_image.jpg", gray)

print("Grayscale image saved successfully")
# Out:
# Grayscale image saved successfully

# %%
# Save image in BMP format
cv2.imwrite("Image/grayscale_image.bmp", gray)

print("JPG image successfully converted to BMP format")
# Out:
# JPG image successfully converted to BMP format

# %%
# Binary thresholding
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Display binary image
plt.imshow(binary, cmap="gray")
plt.title("Binary Image")
plt.axis("off")
plt.show()

# %%
# Save binary image
cv2.imwrite("Image/binary_image.jpg", binary)

print("Binary image saved successfully")
# Out:
# Binary image saved successfully

# %%
# Save image in BMP format
cv2.imwrite("Image/binary_image.bmp", binary)

print("JPG image successfully converted to BMP format")
# Out:
# JPG image successfully converted to BMP format
