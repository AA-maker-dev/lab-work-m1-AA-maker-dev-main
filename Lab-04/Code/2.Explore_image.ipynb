# %%
import cv2
import numpy as np

# Read JPG image
image = cv2.imread(r"Z:\MMS\lab-work-m1-AA-maker-dev-main\Lab-04\Image\1004016.jpg")

# Check if image is loaded
if image is None:
    print("Error: Image not found")
else:
    print("Image loaded successfully")
# Out:
# Image loaded successfully

# %%
# Display image information
height, width, channels = image.shape
print("Height:", height)
print("Width:", width)
print("Channels:", channels)
print("Data type:", image.dtype)
# Out:
# Height: 2400
# Width: 4320
# Channels: 3
# Data type: uint8

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# Read image
image = cv2.imread(r"Z:\MMS\lab-work-m1-AA-maker-dev-main\Lab-04\Image\1004016.jpg")

# Print image properties
print("Image Shape (Height, Width, Channels):", image.shape)
print("Image Data Type:", image.dtype)

# Display pixel value at a specific location
x, y = 100, 100
print(f"Pixel value at ({x},{y}):", image[x, y])
# Out:
# Image Shape (Height, Width, Channels): (2400, 4320, 3)
# Image Data Type: uint8
# Pixel value at (100,100): [114 110  92]

# %%
# Save image in BMP format
cv2.imwrite("Z:\MMS\lab-work-m1-AA-maker-dev-main\Lab-04\Image\1004016.jpg", image)

print("JPG image successfully converted to BMP format")
# Out:
# JPG image successfully converted to BMP format
